# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
clean_application_df = application_df.drop(columns=["EIN","STATUS","SPECIAL_CONSIDERATIONS"])
clean_application_df.head()
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION     INCOME_AMT  \
# 0       Independent          C1000    ProductDev   Association              0
# 1       Independent          C2000  Preservation  Co-operative         1-9999
# 2  CompanySponsored          C3000    ProductDev   Association              0
# 3  CompanySponsored          C2000  Preservation         Trust    10000-24999
# 4       Independent          C1000     Heathcare         Trust  100000-499999
#
#    ASK_AMT  IS_SUCCESSFUL
# 0     5000              1
# 1   108590              1
# 2     5000              0
# ...

# %%
clean_application_df["AFFILIATION"].value_counts()
# Out:
# AFFILIATION
# Independent         18480
# CompanySponsored    15705
# Family/Parent          64
# National               33
# Regional               13
# Other                   4
# Name: count, dtype: int64

# %%
clean_application_df["USE_CASE"].value_counts()
# Out:
# USE_CASE
# Preservation     28095
# ProductDev        5671
# CommunityServ      384
# Heathcare          146
# Other                3
# Name: count, dtype: int64

# %%
cutoff = 500
use_counts = clean_application_df["USE_CASE"].value_counts()
uses_to_replace = list(use_counts[use_counts < cutoff].index)

# Replace in dataframe
for use in uses_to_replace:
    clean_application_df['USE_CASE'] = clean_application_df['USE_CASE'].replace(use,"Other")

# Check to make sure replacement was successful
clean_application_df['USE_CASE'].value_counts()
# Out:
# USE_CASE
# Preservation    28095
# ProductDev       5671
# Other             533
# Name: count, dtype: int64

# %%
cutoff = 10000
org_counts = clean_application_df["ORGANIZATION"].value_counts()
orgs_to_replace = list(org_counts[org_counts < cutoff].index)

# Replace in dataframe
for org in orgs_to_replace:
    clean_application_df['ORGANIZATION'] = clean_application_df['ORGANIZATION'].replace(org,"Other")

# Check to make sure replacement was successful
clean_application_df['ORGANIZATION'].value_counts()
# Out:
# ORGANIZATION
# Trust          23515
# Association    10255
# Other            529
# Name: count, dtype: int64

# %%
clean_application_df["AFFILIATION"].value_counts()
# Out:
# AFFILIATION
# Independent         18480
# CompanySponsored    15705
# Family/Parent          64
# National               33
# Regional               13
# Other                   4
# Name: count, dtype: int64

# %%
cutoff = 100
aff_counts = clean_application_df["AFFILIATION"].value_counts()
aff_to_replace = list(aff_counts[aff_counts < cutoff].index)

# Replace in dataframe
for aff in aff_to_replace:
    clean_application_df['AFFILIATION'] = clean_application_df['AFFILIATION'].replace(aff,"Other")

# Check to make sure replacement was successful
clean_application_df['AFFILIATION'].value_counts()
# Out:
# AFFILIATION
# Independent         18480
# CompanySponsored    15705
# Other                 114
# Name: count, dtype: int64

# %%
# Determine the number of unique values in each column.
clean_application_df.nunique()
# Out:
# NAME                19568
# APPLICATION_TYPE       17
# AFFILIATION             3
# CLASSIFICATION         71
# USE_CASE                3
# ORGANIZATION            3
# INCOME_AMT              9
# ASK_AMT              8747
# IS_SUCCESSFUL           2
# dtype: int64

# %%
# Look at NAME value counts to identify and replace with "Other"
clean_application_df["NAME"].value_counts()
# Out:
# NAME
# PARENT BOOSTER USA INC                                                  1260
# TOPS CLUB INC                                                            765
# UNITED STATES BOWLING CONGRESS INC                                       700
# WASHINGTON STATE UNIVERSITY                                              492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                          408
#                                                                         ...
# ST LOUIS SLAM WOMENS FOOTBALL                                              1
# AIESEC ALUMNI IBEROAMERICA CORP                                            1
# WEALLBLEEDRED ORG INC                                                      1
# AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI       1
# WATERHOUSE CHARITABLE TR                                                   1
# Name: count, Length: 19568, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `names_to_replace`
cutoff = 50
name_counts = clean_application_df["NAME"].value_counts()
names_to_replace = list(name_counts[name_counts <= cutoff].index)

# Replace in dataframe
for name in names_to_replace:
    clean_application_df['NAME'] = clean_application_df['NAME'].replace(name,"Other")

# Check to make sure replacement was successful
clean_application_df['NAME'].value_counts()
# Out:
# NAME
# Other                                                                 24645
# PARENT BOOSTER USA INC                                                 1260
# TOPS CLUB INC                                                           765
# UNITED STATES BOWLING CONGRESS INC                                      700
# WASHINGTON STATE UNIVERSITY                                             492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                         408
# PTA TEXAS CONGRESS                                                      368
# SOROPTIMIST INTERNATIONAL OF THE AMERICAS INC                           331
# ALPHA PHI SIGMA                                                         313
# TOASTMASTERS INTERNATIONAL                                              293
# MOST WORSHIPFUL STRINGER FREE AND ACCEPTED MASONS                       287
# LITTLE LEAGUE BASEBALL INC                                              277
# ...

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
clean_application_df["APPLICATION_TYPE"].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# You may find it helpful to look at APPLICATION_TYPE value counts >1
name_counts = clean_application_df["APPLICATION_TYPE"].value_counts()
name_counts[name_counts > 1]
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of applications to be replaced
# use the variable name `apps_to_replace`
cutoff = 1000
class_counts = clean_application_df["APPLICATION_TYPE"].value_counts()
apps_to_replace = list(class_counts[class_counts < cutoff].index)
# Replace in dataframe
for app in apps_to_replace:
    clean_application_df['APPLICATION_TYPE'] = clean_application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
clean_application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: count, dtype: int64

# %%
cutoff = 100
class_counts = clean_application_df["CLASSIFICATION"].value_counts()
apps_to_replace = list(class_counts[class_counts < cutoff].index)
# Replace in dataframe
for app in apps_to_replace:
    clean_application_df['CLASSIFICATION'] = clean_application_df['CLASSIFICATION'].replace(app,"Other")

# Check to make sure replacement was successful
clean_application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: count, dtype: int64

# %%
class_counts = application_df["CLASSIFICATION"].value_counts()
class_counts[class_counts > 100]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
clean_application_df = pd.get_dummies(clean_application_df)
clean_application_df.head()
# Out:
#    ASK_AMT  IS_SUCCESSFUL  NAME_AIR FORCE ASSOCIATION  NAME_ALPHA PHI SIGMA  \
# 0     5000              1                       False                 False
# 1   108590              1                       False                 False
# 2     5000              0                       False                 False
# 3     6692              1                       False                 False
# 4   142590              1                       False                 False
#
#    NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES INC  \
# 0                                              False
# 1                                              False
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = clean_application_df.drop(columns=["IS_SUCCESSFUL"]).values
y = clean_application_df["IS_SUCCESSFUL"].values
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train[0])
nodes_layer1 = 50
nodes_layer3 = 30
nodes_layer2 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=nodes_layer1,input_dim=input_features,activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=nodes_layer2,activation="sigmoid"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=nodes_layer3,activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 50)                  │           4,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             510 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# Compile the model
nn.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
# Train the model
model_fit = nn.fit(X_train_scaled,y_train,epochs=150)
# Out:
# Epoch 1/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7698 - loss: 0.4671
# Epoch 2/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7737 - loss: 0.4592
# Epoch 3/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7759 - loss: 0.4589
# Epoch 4/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7729 - loss: 0.4626
# Epoch 5/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7689 - loss: 0.4642
# Epoch 6/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7689 - loss: 0.4658
# Epoch 7/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7703 - loss: 0.4665
# Epoch 8/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7736 - loss: 0.4598
# Epoch 9/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7721 - loss: 0.4604
# Epoch 10/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7720 - loss: 0.4601
# Epoch 11/150
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - 1ms/step - accuracy: 0.7586 - loss: 0.4931
# Loss: 0.49310502409935, Accuracy: 0.7586005926132202

# %%
# Export our model to HDF5 file
nn.save("/content/drive/MyDrive/AlphabetSoupCharity_Optimization3.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
